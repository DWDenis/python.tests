# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('FII.csv', sep=";")

df.head()
# Out:
#     Papel             Segmento Cotacao FFO Yield Dividend Yield  P/VP  \
# 0  AAZQ11  Titulos e Val. Mob.    6,62    21,94%         18,12%  0,76
# 1  ABCP11            Shoppings   75,03     8,24%          8,86%  0,74
# 2  AEFI11               Outros   174,9     8,89%          0,00%   1,2
# 3  AFCR11              Hibrido  103,15     6,80%          0,00%  1,05
# 4  AFHI11  Titulos e Val. Mob.   94,18     9,98%         11,46%  0,99
#
#   Valor de Mercado   Liquidez  Qtd de imoveis Preco do m2 Aluguel por m2  \
# 0      159.127.000    800.052               0           0              0
# 1      353.322.000     58.154               1    4.934,93         511,02
# 2      411.893.000          0               7    4.316,30         394,34
# 3      498.867.000          0               0           0              0
# 4      429.048.000  1.244.800               0           0              0
#
#   Cap Rate Vacancia Media
# 0    0,00%          0,00%
# 1   10,36%          2,01%
# ...

# %%
df[df['Cotacao']>7]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df[df['Cotacao']>7]
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\series.py:6119, in Series._cmp_method(self, other, op)
#    6116 lvalues = self._values
#    6117 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# ...
