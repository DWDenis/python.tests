# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Setting to make numbers easier to read on display
pd.options.display.float_format = '{:20.2f}'.format

# Show all columns on output
pd.set_option('display.max_columns', 999)

# %%
df = pd.read_csv('fraud_data.csv')

# %%
df.columns
# Out:
# Index(['trans_date_trans_time', 'merchant', 'category', 'amt', 'city', 'state',
#        'lat', 'long', 'city_pop', 'job', 'dob', 'trans_num', 'merch_lat',
#        'merch_long', 'is_fraud'],
#       dtype='object')

# %%
df.head()
# Out:
#   trans_date_trans_time                          merchant        category  \
# 0      04-01-2019 00:58  "Stokes, Christiansen and Sipes"     grocery_net
# 1      04-01-2019 15:06                      Predovic Inc    shopping_net
# 2      04-01-2019 22:37                   Wisozk and Sons        misc_pos
# 3      04-01-2019 23:06                    Murray-Smitham     grocery_pos
# 4      04-01-2019 23:59                        Friesen Lt  health_fitness
#
#                    amt   city state                  lat                 long  \
# 0                14.37  Wales    AK                64.76              -165.67
# 1               966.11  Wales    AK                64.76              -165.67
# 2                49.61  Wales    AK                64.76              -165.67
# 3               295.26  Wales    AK                64.76              -165.67
# 4                18.17  Wales    AK                64.76              -165.67
#
# ...

# %%
# formating the date to datetime, especefying the format
df['trans_date_trans_time'] = pd.to_datetime(df['trans_date_trans_time'], format='%d-%m-%Y %H:%M')
#dividing the columns specyfing the format
df['time'] = df['trans_date_trans_time'].dt.strftime('%H:%M')
df['date'] = df['trans_date_trans_time'].dt.date

df.head()
# Out:
#   trans_date_trans_time                          merchant        category  \
# 0   2019-01-04 00:58:00  "Stokes, Christiansen and Sipes"     grocery_net
# 1   2019-01-04 15:06:00                      Predovic Inc    shopping_net
# 2   2019-01-04 22:37:00                   Wisozk and Sons        misc_pos
# 3   2019-01-04 23:06:00                    Murray-Smitham     grocery_pos
# 4   2019-01-04 23:59:00                        Friesen Lt  health_fitness
#
#                    amt   city state                  lat                 long  \
# 0                14.37  Wales    AK                64.76              -165.67
# 1               966.11  Wales    AK                64.76              -165.67
# 2                49.61  Wales    AK                64.76              -165.67
# 3               295.26  Wales    AK                64.76              -165.67
# 4                18.17  Wales    AK                64.76              -165.67
#
# ...

# %%
fraud = df.filter(items= ['time', 'date', 'state', 'city', 'merchant', 'category','job', 'amt', 'is_fraud'])

# %%
fraud.set_index(['state'])

fraud.sort_index()
# Out:
#         time        date state        city                          merchant  \
# 0      00:58  2019-01-04    AK       Wales  "Stokes, Christiansen and Sipes"
# 1      15:06  2019-01-04    AK       Wales                      Predovic Inc
# 2      22:37  2019-01-04    AK       Wales                   Wisozk and Sons
# 3      23:06  2019-01-04    AK       Wales                    Murray-Smitham
# 4      23:59  2019-01-04    AK       Wales                        Friesen Lt
# ...      ...         ...   ...         ...                               ...
# 14441  00:37  2019-01-22    OR      Athena                      Hudson-Grady
# 14442  00:41  2019-01-22    OR    Gardiner    "Nienow, Ankunding and Collie"
# 14443  00:42  2019-01-22    WY        Alva                  Pacocha-O'Reilly
# 14444  00:48  2019-01-22    AK       Wales     "Bins, Balistreri and Beatty"
# 14445  00:55  2019-01-22    MO  Unionville                Daugherty-Thompson
#
# ...

# %%
fraud.groupby('state').max()
# Out:
#         time        date                       city        merchant category  \
# state
# AK     23:59  2020-12-31                      Wales    Zemlak Group   travel
# AZ     23:58  2020-12-31                   Superior      Zulauf LLC   travel
# CA     23:59  2020-12-31                     Wendel      Zulauf LLC   travel
# CO     23:58  2020-12-31                  Red Cliff      Zulauf LLC   travel
# HI     23:49  2020-12-31                    Paauilo  Ziemann-Waters   travel
# ID     23:59  2020-12-31                Spirit Lake      Zulauf LLC   travel
# MO     23:59  2020-12-31               Williamsburg      Zulauf LLC   travel
# NE     23:59  2020-12-31                Westerville      Zulauf LLC   travel
# NM     23:59  2020-12-31                    Ruidoso      Zulauf LLC   travel
# OR     23:59  2020-12-31                    Westfir      Zulauf LLC   travel
# UT     23:59  2020-12-31                Woods Cross  Ziemann-Waters   travel
# ...
